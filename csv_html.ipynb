# %%
import pandas as pd

# %%
cities_df = pd.read_csv('resources/weather_cites.csv')

# %%
cities_df
# Out:
#      City_ID                 City      Lat       Lng  Max Temp  Humidity  \
# 0          0              sompeta  18.9333   84.6000     72.00        58
# 1          1              fomboni -12.2800   43.7425     82.15        73
# 2          2           butaritari   3.0707  172.7902     80.38        78
# 3          3          yellowknife  62.4560 -114.3525    -25.08        75
# 4          4        mar del plata -38.0023  -57.5575     68.95        88
# ..       ...                  ...      ...       ...       ...       ...
# 578      578             kaffrine  14.1059  -15.5508     69.67        17
# 579      579         richards bay -28.7830   32.0377     73.04        92
# 580      580              manyana -23.4000   21.7167     66.00        90
# 581      581  barra dos coqueiros -10.9089  -37.0386     78.82        78
# 582      582              okhotsk  59.3833  143.3000      0.00        95
#
#      Cloudiness  Wind Speed Country                 Date
# ...

# %%
cities_df.to_html('cities.html',index=False)
